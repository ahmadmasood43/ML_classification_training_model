# %%
from google.colab import files
files.upload ()
# Out:
#      <input type="file" id="files-7267f121-e7d3-4a25-9d7b-b4a21a1b0d6f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7267f121-e7d3-4a25-9d7b-b4a21a1b0d6f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"ahmadmas00d","key":"81a07911c931ce002d13433b62b47c00"}'}

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d linchundan/fundusimage1000
# !unzip fundusimage1000
# Out:
# ...
# 100% 775M/778M [00:05<00:00, 155MB/s]
# 100% 778M/778M [00:05<00:00, 155MB/s]
# Archive:  fundusimage1000.zip
#   inflating: 1000images/0.0.Normal/1ffa9627-8d87-11e8-9daf-6045cb817f5b..JPG
#   inflating: 1000images/0.0.Normal/1ffa9628-8d87-11e8-9daf-6045cb817f5b..JPG
#   inflating: 1000images/0.0.Normal/1ffa9629-8d87-11e8-9daf-6045cb817f5b..JPG
#   inflating: 1000images/0.0.Normal/1ffa962a-8d87-11e8-9daf-6045cb817f5b..JPG
#   inflating: 1000images/0.0.Normal/1ffa962b-8d87-11e8-9daf-6045cb817f5b..JPG
#   inflating: 1000images/0.0.Normal/1ffa962d-8d87-11e8-9daf-6045cb817f5b..JPG
#   inflating: 1000images/0.0.Normal/1ffa962e-8d87-11e8-9daf-6045cb817f5b..JPG
#   inflating: 1000images/0.0.Normal/1ffa962f-8d87-11e8-9daf-6045cb817f5b..JPG
#   inflating: 1000images/0.0.Normal/1ffa9630-8d87-11e8-9daf-6045cb817f5b..JPG
#   inflating: 1000images/0.0.Normal/1ffa9631-8d87-11e8-9daf-6045cb817f5b..JPG
#   inflating: 1000images/0.0.Normal/1ffa9632-8d87-11e8-9daf-6045cb817f5b..JPG
# ...

# %%
import shutil
#BRVO || CRVO || Preretinal hemorrhage
shutil.copytree('/content/1000images/2.0.BRVO', '/content/newfolder/2.0.BRVO')
shutil.copytree('/content/1000images/2.1.CRVO', '/content/newfolder/2.1.CRVO')
shutil.copytree('/content/1000images/25.Preretinal hemorrhage', '/content/newfolder/25.Preretinal hemorrhage')
# Out:
# '/content/newfolder/25.Preretinal hemorrhage'

# %%
  import tensorflow as tf
  import numpy as np
  import matplotlib.pyplot as plt

# %%
IMAGE_HEIGHT = 150
IMAGE_WIDTH = 150
BATCH_SIZE = 32

# %%
  TRAIN_DIR = "/content/newfolder"

# %%
train_data = tf.keras.preprocessing.image_dataset_from_directory(
  TRAIN_DIR,
  validation_split=0.15,
  color_mode = "grayscale",
  subset= 'training',
  seed=124,
  image_size = (IMAGE_WIDTH,IMAGE_HEIGHT),
  batch_size =32  
)
# Out:
# Found 76 files belonging to 3 classes.
# Using 65 files for training.

# %%
val_data = tf.keras.preprocessing.image_dataset_from_directory(
  TRAIN_DIR,
  validation_split=0.15,
  subset= 'validation',
  color_mode = "grayscale",
  seed=124,
  image_size = (IMAGE_WIDTH,IMAGE_HEIGHT),
  batch_size =32  
)
# Out:
# Found 76 files belonging to 3 classes.
# Using 11 files for validation.

# %%
class_names = train_data.class_names

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

num_classes = 5

model = Sequential([
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(IMAGE_HEIGHT,IMAGE_WIDTH, 1)),
                    layers.Conv2D(64,3,padding= 'same',activation='relu'),
                    layers.MaxPooling2D(),
                    layers.Conv2D(32,3,padding ='same',activation='relu'),
                    layers.MaxPooling2D(),
                    layers.Conv2D(16, 3,padding= 'same', activation= 'relu'),
                    layers.MaxPooling2D(),
                    layers.Flatten(),
                    layers.Dense(128,activation = 'relu'),
                    layers.Dense(num_classes)
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# rescaling (Rescaling)        (None, 150, 150, 1)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 150, 150, 64)      640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 32)        18464
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 16)        4624
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 16)        0
# ...

# %%
model.compile(optimizer="adam", loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])

# %%
model.fit(train_data,epochs=20)
# Out:
# Epoch 1/20
# 3/3 [==============================] - 30s 102ms/step - loss: 1.4788 - accuracy: 0.5846
# Epoch 2/20
# 3/3 [==============================] - 1s 47ms/step - loss: 1.0171 - accuracy: 0.4154
# Epoch 3/20
# 3/3 [==============================] - 1s 44ms/step - loss: 1.0506 - accuracy: 0.5846
# Epoch 4/20
# 3/3 [==============================] - 1s 40ms/step - loss: 1.0651 - accuracy: 0.5846
# Epoch 5/20
# 3/3 [==============================] - 1s 38ms/step - loss: 0.9877 - accuracy: 0.5846
# Epoch 6/20
# 3/3 [==============================] - 1s 42ms/step - loss: 0.9744 - accuracy: 0.5846
# Epoch 7/20
# 3/3 [==============================] - 1s 35ms/step - loss: 0.9933 - accuracy: 0.5846
# Epoch 8/20
# 3/3 [==============================] - 1s 35ms/step - loss: 0.9423 - accuracy: 0.5846
# Epoch 9/20
# 3/3 [==============================] - 1s 36ms/step - loss: 0.9274 - accuracy: 0.5846
# Epoch 10/20
# ...

# %%
import cv2
image = cv2.imread("/content/newfolder/2.0.BRVO/1ffa95f1-8d87-11e8-9daf-6045cb817f5b..JPG", cv2.IMREAD_GRAYSCALE)
image = cv2.resize(image,(IMAGE_HEIGHT,IMAGE_WIDTH),interpolation = cv2.INTER_AREA)

# %%
resp = model.predict(np.expand_dims(image, axis=0))
class_names[np.argmax(resp)]
print(resp)
print(class_names[np.argmax(resp)])
# Out:
# [[ 2.932902   2.829611   0.9771526 -3.0012193 -3.7774732]]
# 2.0.BRVO
